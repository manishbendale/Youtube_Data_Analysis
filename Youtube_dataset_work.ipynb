# %%
import pandas as pd

# %%
youtube = pd.read_csv("youtube.csv", names = ['v_id', 'v_uploader', 'v_interval', 'v_category', 'v_length', 'views_count', 'v_rating', 'no_ratings_given', 'comments_count', 'v_ids_related','v_ids_related_1','v_ids_related_2','v_ids_related_3','v_ids_related_4','v_ids_related_5','v_ids_related_6','v_ids_related_7','v_ids_related_8','v_ids_related_9','v_ids_related_10','v_ids_related_11','v_ids_related_12','v_ids_related_13','v_ids_related_14'], delimiter = '\t', header = None)
youtube.head()
# Out:
#           v_id            v_uploader  v_interval      v_category  v_length  \
# 0  QuRYeRnAuXM  EvilSquirrelPictures      1135.0  Pets & Animals     252.0
# 1  3TYqkBJ9YRk                hggh22      1135.0          Comedy     169.0
# 2  rSJ8QZWBegU               TimeGem      1135.0   Entertainment      95.0
# 3  nRcovJn9xHg            wooochacha      1135.0   Entertainment     118.0
# 4  UEvVksP91kg              johnx113      1135.0   Entertainment      83.0
#
#    views_count  v_rating  no_ratings_given  comments_count v_ids_related  \
# 0       1075.0      4.96              46.0            86.0   gFa1YMEJFag
# 1        228.0      5.00               5.0             3.0   QuRYeRnAuXM
# 2        356.0      4.31              13.0             1.0   QuRYeRnAuXM
# 3       1115.0      2.23              57.0            73.0   QuRYeRnAuXM
# 4        281.0      2.67               9.0            16.0   gFa1YMEJFag
#
#         ...        v_ids_related_5 v_ids_related_6 v_ids_related_7  \
# 0       ...            UEvVksP91kg     ZTopArY7Nbg     0RViGi2Rne8
# 1       ...            sVkuOk4jmCo     ZTopArY7Nbg     HT_QlOJbDpg
# 2       ...            sVkuOk4jmCo     ZTopArY7Nbg     gBcu22Vv1nY
# 3       ...            gBcu22Vv1nY     HT_QlOJbDpg     0RViGi2Rne8
# 4       ...            nRcovJn9xHg     sVkuOk4jmCo     ZTopArY7Nbg
#
#   v_ids_related_8 v_ids_related_9 v_ids_related_10 v_ids_related_11  \
# 0     HT_QlOJbDpg     YZev1imoxX8      8qQrrfUTmh0      zQ83d_D2MGs
# 1     0RViGi2Rne8     ShhClb6J-NA      g9e1alirMhc      YZev1imoxX8
# 2     HT_QlOJbDpg     0RViGi2Rne8      ShhClb6J-NA      g9e1alirMhc
# 3     ShhClb6J-NA     g9e1alirMhc      YZev1imoxX8      I4yKEK9o8gA
# 4     HT_QlOJbDpg     0RViGi2Rne8      g9e1alirMhc      YZev1imoxX8
#
#   v_ids_related_12 v_ids_related_13 v_ids_related_14
# 0      u6_DQQjLsAw      73Wz9CQFDtE              NaN
# 1      I4yKEK9o8gA      zQ83d_D2MGs      1GKaVzNDbuI
# 2      YZev1imoxX8      I4yKEK9o8gA      zQ83d_D2MGs
# 3      zQ83d_D2MGs      1GKaVzNDbuI      yuZhwV24PmM
# 4      I4yKEK9o8gA      zQ83d_D2MGs      1GKaVzNDbuI
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Find out the top 5 categories with maximum number of videos uploaded

# %%
categories = youtube.v_category.value_counts()
categories.head()
# Out:
# Entertainment      908
# Music              862
# Comedy             414
# People & Blogs     398
# News & Politics    333
# Name: v_category, dtype: int64

# %% [markdown]
# ## Find out the top 10 rated videos

# %%
rated_video = youtube.no_ratings_given.sort_values(ascending = False)
rated_video.head(10)
# Out:
# 1053    122129.0
# 1128     83514.0
# 2547     75004.0
# 3880     73257.0
# 3690     58850.0
# 1763     56767.0
# 969      43774.0
# 1104     37247.0
# 538      35352.0
# 3876     34802.0
# Name: no_ratings_given, dtype: float64

# %%
top_rated = youtube.sort_values(['no_ratings_given'], ascending= False)
top_rated.head(10)
# Out:
#              v_id       v_uploader  v_interval       v_category  v_length  \
# 1053  kHmvkRoEowc  itschriscrocker       937.0    Entertainment     131.0
# 1128  EwTZ2xpQwpA        TayZonday       796.0            Music     292.0
# 2547  rZBA0SKmQy8      TownIdiot25       848.0           Comedy     130.0
# 3880  4DC4Rb9quKk     ChrisBrownTV       933.0            Music     265.0
# 3690  LU8DDYz68kM         Jason275       807.0   Pets & Animals     503.0
# 1763  Qit3ALTelOo         smpfilms       932.0   Pets & Animals     210.0
# 969   irp8CNj9qBI      Frozentoast       215.0            Music     349.0
# 1104  3QL97xldoXc       thePranker       772.0  Travel & Events     358.0
# 538   LTxO_pgMqys        machinima       969.0    Entertainment     407.0
# 3876  Md6rURKhZmA      TPainVideos       857.0            Music     240.0
#
#       views_count  v_rating  no_ratings_given  comments_count v_ids_related  \
# 1053   18235463.0      2.42          122129.0        259683.0   h863nXDqCM0
# 1128   16841569.0      4.23           83514.0        129200.0   2x2W12A8Qow
# 2547   11007201.0      4.83           75004.0         30666.0   YXZjh0Cejvc
# 3880   33754615.0      4.84           73257.0         50036.0   OqumjziPTzk
# 3690   27721690.0      4.88           58850.0         24004.0   VryQDsx5Ad8
# 1763    7939352.0      4.76           56767.0         39418.0   DpA2tMrQ4RU
# 969    10172172.0      4.90           43774.0         29330.0   cxbFLYa0_bw
# 1104    3010296.0      3.44           37247.0         19461.0   84_y1mWPaUk
# 538     3731016.0      4.82           35352.0         26192.0   0RWQ7R555i4
# 3876   18141492.0      4.83           34802.0         17731.0   Oy-nqyfR_w4
#
#            ...        v_ids_related_5 v_ids_related_6 v_ids_related_7  \
# 1053       ...            O6Bqf23u-40     g0VRkCF2a80     VVcmHcHIsYc
# 1128       ...            hjD6iigdB-g     caIBKOztlAo     xUz2YMmiq0k
# 2547       ...            4xPOXSfPQGE     EtOoQFa5ug8     02tVq5OKVkQ
# 3880       ...            xaYiv-mDOwo     Oy-nqyfR_w4     a1fZHmIggc8
# 3690       ...            1a4-jwXejc0     h1FivamFXms     LB4iy0Hsc3Y
# 1763       ...            UDJNuypavq8     dQqingUyRWg     CjUTnQKrFgQ
# 969        ...            hMenB9Ywh2Q     MMz-wi50ACU     C7FGPIRJx6I
# 1104       ...            gXy65PoXqvM     eejQPUyeNiY     U9bg0Bifk08
# 538        ...            OJWBmuioqJU     kb8rdc-0OpQ     ym0BtwmCvoc
# 3876       ...            8hvEsCUj0xQ     A2f3cuUXXRs     D9g2szHsoz0
#
#      v_ids_related_8 v_ids_related_9 v_ids_related_10 v_ids_related_11  \
# 1053     wYBI_0qGwXg     hoKlMpCW0Vc      244qR7SvvX0      uEE3akeFeQU
# 1128     aWY3eYOX3U0     mD5_GUovjiM      1oFS-q8BIps      deXAEN70CDY
# 2547     WGooQ8yYC0c     q6jqbx7t64A      DpJyG7B6tAI      jkyhqE_VOEE
# 3880     -hXKRilPNpc     R_C4aWwznNQ      mpxw0iCP4q4      gY-zTUCxgD0
# 3690     2cyu7tUEgs4     sDYxC2r3ttw      fI1RH1VhlYI      trQP5TtG_SY
# 1763     lIK5Gn5HbnU     RoBKq_RRoCM      Kxa0mnDj0bs      Zi9GOvR3Ynw
# 969      EVYgRPfC9nQ     7GFpMb0sOaw      veTm1sZz2eo      pZ9jrBg4Lwc
# 1104     gmD08XAesPI     7f0LXxryPFs      GnXMUCvqXWs      Re6apUfHv-8
# 538      2pNTrYd-4FQ     uCsdPszJLNQ      ncGCKsVIjuE      A7LQ7i7tzRE
# 3876     IG5ReXP0SSg     ichSb-1HSiY      7PxBGHjABnU      HS7aULdHo24
#
#      v_ids_related_12 v_ids_related_13 v_ids_related_14
# 1053      aiqkDm9UoKo      Yd1Oe1LELcc              NaN
# 1128      0pElTyjfxe0      eyDuGwlrFRs      m6SjPfc_xNA
# 2547      kDIm7zyXRKM      _1nzEFMjkI4              NaN
# 3880      A2f3cuUXXRs      FxTMfsRQIng      ktUSIJEiOug
# 3690      YOE4RzS7JPY      3ZUzsKxeXcs      SWWTpkX-d4Y
# 1763      Luxgpavp6V0      UOY0cXOq3a8      hAYhfDSbWIY
# 969       NCo1OVNbYFQ      IOyEw9bT8yQ      CO9UN6hfCS4
# 1104      6GbQpEQgFxw      oVm5fzfjggg              NaN
# 538       jfx8kcS0KiU      zwp3HEwA1oM      9Vi45QBGsWE
# 3876      veYbj2zypaM      5f7kfhHHH_A      HiBcQeIax4g
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Find out the 10 most viewed videos.

# %%
top_viewed = youtube.sort_values(['views_count'], ascending= False)
top_viewed.head(10)
# Out:
#              v_id       v_uploader  v_interval        v_category  v_length  \
# 1109  12Z3J1uzd0Q          kaejane       404.0  Film & Animation     615.0
# 3880  4DC4Rb9quKk     ChrisBrownTV       933.0             Music     265.0
# 3690  LU8DDYz68kM         Jason275       807.0    Pets & Animals     503.0
# 1053  kHmvkRoEowc  itschriscrocker       937.0     Entertainment     131.0
# 3876  Md6rURKhZmA      TPainVideos       857.0             Music     240.0
# 1128  EwTZ2xpQwpA        TayZonday       796.0             Music     292.0
# 3886  A2f3cuUXXRs         RKellyTV       751.0             Music     326.0
# 2547  rZBA0SKmQy8      TownIdiot25       848.0            Comedy     130.0
# 969   irp8CNj9qBI      Frozentoast       215.0             Music     349.0
# 4063  ZCYaw5tGYAs         nozzle49       529.0            Comedy      80.0
#
#       views_count  v_rating  no_ratings_given  comments_count v_ids_related  \
# 1109   65341925.0      3.03            9189.0          5508.0   innfyQZHPpo
# 3880   33754615.0      4.84           73257.0         50036.0   OqumjziPTzk
# 3690   27721690.0      4.88           58850.0         24004.0   VryQDsx5Ad8
# 1053   18235463.0      2.42          122129.0        259683.0   h863nXDqCM0
# 3876   18141492.0      4.83           34802.0         17731.0   Oy-nqyfR_w4
# 1128   16841569.0      4.23           83514.0        129200.0   2x2W12A8Qow
# 3886   13038204.0      4.80           18910.0         11315.0   Md6rURKhZmA
# 2547   11007201.0      4.83           75004.0         30666.0   YXZjh0Cejvc
# 969    10172172.0      4.90           43774.0         29330.0   cxbFLYa0_bw
# 4063    8944331.0      4.86           16551.0          6938.0   58CZcCvwND4
#
#            ...        v_ids_related_5 v_ids_related_6 v_ids_related_7  \
# 1109       ...            5P6UU6m3cqk     uBHsOTYO6AI     lW19DnWz6vg
# 3880       ...            xaYiv-mDOwo     Oy-nqyfR_w4     a1fZHmIggc8
# 3690       ...            1a4-jwXejc0     h1FivamFXms     LB4iy0Hsc3Y
# 1053       ...            O6Bqf23u-40     g0VRkCF2a80     VVcmHcHIsYc
# 3876       ...            8hvEsCUj0xQ     A2f3cuUXXRs     D9g2szHsoz0
# 1128       ...            hjD6iigdB-g     caIBKOztlAo     xUz2YMmiq0k
# 3886       ...            kEUtFmx6ETE     -cZeF1sG0h8     veYbj2zypaM
# 2547       ...            4xPOXSfPQGE     EtOoQFa5ug8     02tVq5OKVkQ
# 969        ...            hMenB9Ywh2Q     MMz-wi50ACU     C7FGPIRJx6I
# 4063       ...            7tRWRSfcDuQ     CoiFGva_JoY     8NvZTOWrpNQ
#
#      v_ids_related_8 v_ids_related_9 v_ids_related_10 v_ids_related_11  \
# 1109     vr3x_RRJdd4     5GE82tqcYYQ      D2kJZOfq7zk      lsO6D1rwrKc
# 3880     -hXKRilPNpc     R_C4aWwznNQ      mpxw0iCP4q4      gY-zTUCxgD0
# 3690     2cyu7tUEgs4     sDYxC2r3ttw      fI1RH1VhlYI      trQP5TtG_SY
# 1053     wYBI_0qGwXg     hoKlMpCW0Vc      244qR7SvvX0      uEE3akeFeQU
# 3876     IG5ReXP0SSg     ichSb-1HSiY      7PxBGHjABnU      HS7aULdHo24
# 1128     aWY3eYOX3U0     mD5_GUovjiM      1oFS-q8BIps      deXAEN70CDY
# 3886     8hvEsCUj0xQ     EJWfQ6ISA4o      ZLTgw5hbges      gXmG07kMMmU
# 2547     WGooQ8yYC0c     q6jqbx7t64A      DpJyG7B6tAI      jkyhqE_VOEE
# 969      EVYgRPfC9nQ     7GFpMb0sOaw      veTm1sZz2eo      pZ9jrBg4Lwc
# 4063     n9nvFmfDUTs     wKMnausIyzM      uxZabf3u89s      LEEI2LlLyyw
#
#      v_ids_related_12 v_ids_related_13 v_ids_related_14
# 1109      dMH0bHeiRNg      kNLXjXxj3J8      vQbYvjmfbr4
# 3880      A2f3cuUXXRs      FxTMfsRQIng      ktUSIJEiOug
# 3690      YOE4RzS7JPY      3ZUzsKxeXcs      SWWTpkX-d4Y
# 1053      aiqkDm9UoKo      Yd1Oe1LELcc              NaN
# 3876      veYbj2zypaM      5f7kfhHHH_A      HiBcQeIax4g
# 1128      0pElTyjfxe0      eyDuGwlrFRs      m6SjPfc_xNA
# 3886      y0_G0m5W1nY      yhTQ-hC9-IQ      Ywlm-LPftOY
# 2547      kDIm7zyXRKM      _1nzEFMjkI4              NaN
# 969       NCo1OVNbYFQ      IOyEw9bT8yQ      CO9UN6hfCS4
# 4063      FzRH3iTQPrk      kdeVpw9rNyg      _xDghiPswLM
#
# [10 rows x 24 columns]
